# %% [markdown]
# <a href="https://colab.research.google.com/github/bcguilherme/Vendas-arvoredecisao/blob/main/Vendas_arvoredecisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset from Excel file

dados = pd.read_excel('/content/vendas.xlsx')

# %%
# Display the first few rows of the dataset

dados.head()
# Out:
#    media_rating  media_pedidos test cliente_comprou
# 0           1.5             11   No             Yes
# 1           2.5             11   No              No
# 2           2.5             11   No              No
# 3           1.5             13   No             Yes
# 4           2.5             13   No              No

# %% [markdown]
# This section loads a dataset from an Excel file and displays the initial rows to give you an overview of the data.

# %%
# Select relevant features (independent variables)

x = dados[['media_rating', 'media_pedidos', 'test']]

# Select the target variable (dependent variable)

y= dados[['cliente_comprou']]

# %%
# Perform one-hot encoding on the selected features

x = pd.get_dummies(x)

# Display the first few rows of the modified dataset

x.head()
# Out:
#    media_rating  media_pedidos  test_No  test_Yes
# 0           1.5             11        1         0
# 1           2.5             11        1         0
# 2           2.5             11        1         0
# 3           1.5             13        1         0
# 4           2.5             13        1         0

# %% [markdown]
# Here, you're selecting specific features and the target variable. One-hot encoding is applied to convert categorical variables into a format suitable for machine learning models.

# %%
# Import the DecisionTreeClassifier from scikit-learn

from sklearn import tree

# %%
# Create a Decision Tree Classifier instance

arvore_decisao = tree.DecisionTreeClassifier()

# %%
# Fit the model using the encoded features and target variable

modelo_ad = arvore_decisao.fit(dados_codificado, y)

# %%
# Display the trained decision tree model

modelo_ad
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# This part of the code imports the DecisionTreeClassifier, creates an instance of it, and fits the model using the dataset.

# %%
# Plot the decision tree


fig = plt.figure(figsize=(40,20))

fig = tree.plot_tree(modelo_ad,
                   feature_names=dados_codificado.columns,
                   class_names=['yes', "no"],
                   filled=True)

# %% [markdown]
# Finally, the decision tree model is visualized using the plot_tree function from scikit-learn's tree module. The visualization includes feature names, class names, and is filled with color to represent different classes.
#
# This code essentially loads a dataset, prepares the data for a decision tree model, trains the model, and visualizes the resulting decision tree.
